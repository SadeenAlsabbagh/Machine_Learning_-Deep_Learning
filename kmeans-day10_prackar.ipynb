# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import os
import numpy as np 
import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/Users/alsabbaghs/Downloads/Raw data for the pressure climate change project-20230209/content/day10.csv')

# %%
min = df.min().min()
max = df.max().max()
print('Min :', min)
print('Max :', max)

cluster = round((max-min)/100)
print('Number of cluster: ', cluster)

X = np.array(df).reshape(-1,1)
kmeans = KMeans(n_clusters=cluster)
kmeans.fit(X)

labels = kmeans.labels_
centroids = kmeans.cluster_centers_ 
print('Centroids: ', centroids)

sorted_centroids = np.sort(centroids, axis=0) 
print('Sorted: ', sorted_centroids)

colors = []
for i in range (len(sorted_centroids)):
  colo.round(0).astype(int)
print(colors)

cluster_labels = kmeans.fit_predict(X)
print(cluster_labels)

img = colors[cluster_labels].reshape(df.shape)
plt.imshow(img, cmap='gray')
plt.show()
# Out:
# Min : 10557
# Max : 12410
# Number of cluster:  19
# Centroids:  [[12099.18503119]
#  [10911.01348315]
#  [11554.30102041]
#  [10702.29950495]
#  [12352.60638298]
#  [11235.87850467]
#  [11823.62390671]
#  [11017.53233831]
#  [11451.58333333]
#  [12001.59114583]
#  [12278.82160393]
#  [11652.80462725]
#  [10806.08018868]
#  [11125.45508982]
#  [10601.1358811 ]
#  [11347.52631579]
#  [11741.15291262]
#  [12191.91304348]
#  [11911.17714286]]
# Sorted:  [[10601.1358811 ]
#  [10702.29950495]
#  [10806.08018868]
#  [10911.01348315]
#  [11017.53233831]
#  [11125.45508982]
#  [11235.87850467]
#  [11347.52631579]
#  [11451.58333333]
#  [11554.30102041]
#  [11652.80462725]
#  [11741.15291262]
#  [11823.62390671]
#  [11911.17714286]
#  [12001.59114583]
#  [12099.18503119]
#  [12191.91304348]
#  [12278.82160393]
#  [12352.60638298]]
# [[10601]
#  [10702]
#  [10806]
#  [10911]
#  [11018]
#  [11125]
#  [11236]
#  [11348]
#  [11452]
#  [11554]
#  [11653]
#  [11741]
#  [11824]
#  [11911]
# ...
