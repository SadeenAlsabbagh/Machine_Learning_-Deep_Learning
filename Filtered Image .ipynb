# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt 
from sklearn.cluster import KMeans 
from skimage import io 
from sklearn.preprocessing import StandardScaler


img= io.imread("/Users/alsabbaghs/Downloads/Lena-original-gray (1).png", as_gray= True)

X = img.reshape(-1,1)

kmeans = KMeans(n_clusters=2)

kmeans.fit(X)

labels = kmeans.labels_
print(min(labels))
print(max(labels))
centroids = kmeans.cluster_centers_
print(centroids)
print(X.shape)

labels = labels.reshape(img.shape)



plt.subplot(121)
plt.imshow(img, cmap='gray')
plt.subplot(122)
plt.imshow(labels, cmap="gray")
plt.show()
# Out:
# 0
# 1
# [[0.57434088]
#  [0.22903609]]
# (117649, 1)

# %%
a = np.array(img)
b = np.array(labels)
result = a*b
result = result.reshape(img.shape)
plt.imshow(result, cmap="gray") #filtered image 
plt.show()



#cluster the highest centriod

# %%
from sklearn.cluster import KMeans
from sklearn import metrics
import numpy as np
import matplotlib.pyplot as plt

a = np.array(img)
b = np.array(labels)

# create new plot and data
plt.plot()
X = np.array(list(zip(a, b))).reshape(len(a), 3)
colors = ['b', 'g']
markers = ['o', 'v']

# KMeans algorithm 
K = 2
kmeans_model = KMeans(n_clusters=K).fit(X)

print(kmeans_model.cluster_centers_)
centers = np.array(kmeans_model.cluster_centers_)

plt.plot()
plt.title('k means centroids')

for i, l in enumerate(kmeans_model.labels_):
    plt.plot(a[i], b[i], color=colors[l], marker=markers[l],ls='None')
    plt.xlim([0, 10])
    plt.ylim([0, 10])

plt.scatter(centers[:,0], centers[:,1], marker="x", color='r')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/pk/79bwkl093mxcs3gstmyz6d7m0000gq/T/ipykernel_1660/3130765039.py in <module>
#       9 # create new plot and data
#      10 plt.plot()
# ---> 11 X = np.array((a, b)).reshape(len(a), 3)
#      12 colors = ['b', 'g']
#      13 markers = ['o', 'v']
#
# ValueError: cannot reshape array of size 235298 into shape (343,3)

# %%
kmeans = KMeans(n_clusters=3)

kmeans.fit(X)

labels = kmeans.labels_
print(min(labels))
print(max(labels))
centroids = kmeans.cluster_centers_
print(centroids)
print(X.shape)

labels = labels.reshape(result.shape)



plt.subplot(121)
plt.imshow(result, cmap='gray')
plt.subplot(122)
plt.imshow(labels, cmap="gray")
plt.show()
# Out:
# 0
# 2
# [[0.44192162]
#  [0.17381393]
#  [0.71171325]]
# (117649, 1)
